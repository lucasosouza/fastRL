# %% [markdown]
# ## Comparison Sarsa and Q-Learning
# ### FrozenLake

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../agents')
sys.path.append('../environments')
sys.path.append('../tools')

import gym
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint
import pandas as pd
from utils import *
from QLearning import QLearning
from SARSA import SARSA
from MonteCarlo import MonteCarlo

# %matplotlib inline

# %%
# initialize env
env = Experiment(gym.make('FrozenLake-v0'))

tries = 10
episodes = 1000
results_QLearning = np.zeros((tries, episodes))
results_MonteCarlo = np.zeros((tries, episodes))

# %% [markdown]
# ### Learning Rate study

# %%
ts = []
lr = .5
episodes = int(1e3)
decay = 1-(1/episodes)*2
for _ in range(episodes):
    ts.append(lr)
    lr = lr*decay

plt.plot(ts)

# %%
ts = []
lr = .8
episodes = int(1e3)
decay = 1-(1/episodes)*3
for _ in range(episodes):
    ts.append(lr)
    lr = lr*decay

plt.plot(ts)

# %% [markdown]
# ### Q-Learning

# %%
epsilon_decay = 1-(1/episodes)*3
learning_decay = 1-(1/episodes)*2

# %%
tries =1
episodes = 100
results_QLearning = np.zeros((tries, episodes))
for t in range(tries):

    agent = QLearning(env.env, learning_rate =0.5, discount_factor=0.9, 
                      exploration_rate=0,
                      epsilon_decay_func = lambda x: x*epsilon_decay,
                      alpha_decay_func = lambda x: x*learning_decay,
                      qtable_default=1
                     )

    # fit and save results
    env.fit(agent, episodes)
    results_QLearning[t, :] = agent.rewards_per_episode

# %%
agent.qtable
# Out:
# {0: {0: 0.11341239598691076,
#   1: 0.11426203826920728,
#   2: 0.11269989890851803,
#   3: 0.11212637107544221},
#  1: {0: 0.10167587331539885,
#   1: 0.06110650972200628,
#   2: 0.06622265813760833,
#   3: 0.10108525786328733},
#  2: {0: 0.12354167466188735,
#   1: 0.12631888809811606,
#   2: 0.1252813503283141,
#   3: 0.1506902286519379},
#  3: {0: 0.1165218300191917,
#   1: 0.12287938049696044,
#   2: 0.13707294716542373,
#   3: 0.1954060378965648},
#  4: {0: 0.19204138030823434,
#   1: 0.08292775246881426,
#   2: 0.11232806425642852,
#   3: 0.07626580472493},
#  5: {0: 1, 1: 1, 2: 1, 3: 1},
#  6: {0: 0.05021976353746095,
#   1: 0.1235908023593077,
#   2: 0.05005367078523435,
#   3: 0.050247169519525486},
#  7: {0: 1, 1: 1, 2: 1, 3: 1},
#  8: {0: 0.16221561885605662,
#   1: 0.1366496003335277,
#   2: 0.14639694004917586,
#   3: 0.28181837713611874},
#  9: {0: 0.25628303721848505,
#   1: 0.3763132090275491,
#   2: 0.21683401973543306,
#   3: 0.17133792864890537},
#  10: {0: 0.24600890259838715,
#   1: 0.1795228417845045,
#   2: 0.17277197109228,
#   3: 0.19799868577144555},
#  11: {0: 1, 1: 1, 2: 1, 3: 1},
#  12: {0: 1, 1: 1, 2: 1, 3: 1},
#  13: {0: 0.23683672865259817,
#   1: 0.2637610185143097,
#   2: 0.555309665995159,
#   3: 0.3298104813558334},
#  14: {0: 0.5109391649801415,
#   1: 0.7546450604143109,
#   2: 0.509435061359677,
#   3: 0.515670283411032},
#  15: {0: 1, 1: 1, 2: 1, 3: 1}}

# %% [markdown]
# ### Monte Carlo Control

# %%
tries =3
episodes = 1000
results_MonteCarlo = np.zeros((tries, episodes))
for t in range(tries):

    agent = MonteCarlo(env.env, discount_factor=0.9, 
                      exploration_rate=0.8,
                      epsilon_decay_func = lambda x: x*epsilon_decay,
                      qtable_default=0
                     )
    # fit and save results
    env.fit(agent, episodes)
    results_MonteCarlo[t, :] = agent.rewards_per_episode

# %%
# plot rewards
# plot_rewards(np.mean(results_QLearning, axis=0), smoothing=0.1, color='blue')
plot_rewards(np.mean(results_MonteCarlo, axis=0), smoothing=0.1, color='green')

# %%
agent.qtable
# Out:
# {0: {0: 0.0011930081510171044,
#   1: 0.02960244107621268,
#   2: 9.713085344933948e-09,
#   3: 0.004847183526804841},
#  1: {0: 1.5133644646704955e-05,
#   1: 1.1475148586503612e-07,
#   2: 1.2699931660864335e-06,
#   3: 0.022289262575889587},
#  2: {0: 1.8576375217735137e-14,
#   1: 2.414436098205282e-28,
#   2: 1.465401919556349e-06,
#   3: 0.020106430214151372},
#  3: {0: 3.0737550764680117e-18,
#   1: 0.022492459339817732,
#   2: 2.9719112416231127e-05,
#   3: 3.840814199194843e-12},
#  4: {0: 0.051327906983130334,
#   1: 0.0017637381800566895,
#   2: 5.662850982851944e-08,
#   3: 0.00015810600262956956},
#  5: {0: 0, 1: 0, 2: 0, 3: 0},
#  6: {0: 9.996318990333087e-12,
#   1: 0.04362053419867396,
#   2: 3.587845605723924e-30,
#   3: 2.6265422817315944e-14},
#  7: {0: 0, 1: 0, 2: 0, 3: 0},
#  8: {0: 0.0007923215836529686,
#   1: 8.462872780180447e-13,
#   2: 5.858915652280075e-17,
#   3: 0.08657723259901216},
#  9: {0: 0.00010851386450036428,
#   1: 5.225169575467472e-44,
#   2: 0.1556247373158848,
#   3: 0.007136093835357661},
#  10: {0: 7.697017825222494e-30,
#   1: 1.1427373486226667e-34,
#   2: 0.17941282793373037,
#   3: 1.873709110618182e-24},
#  11: {0: 0, 1: 0, 2: 0, 3: 0},
#  12: {0: 0, 1: 0, 2: 0, 3: 0},
#  13: {0: 0.0003992481831002719,
#   1: 0.29502302379217504,
#   2: 0,
#   3: 5.483119908249658e-25},
#  14: {0: 0, 1: 0.5825251438070509, 2: 0, 3: 0},
#  15: {0: 0, 1: 0, 2: 0, 3: 0}}

# %% [markdown]
# MC is significantly slower than TD, since it has the improvement state that goes through all states. If I only change the value function of visited states, should I instead only update for the visited state? But having update one visited state can change the action-value of another state that leads to that. It just seems inefficient
